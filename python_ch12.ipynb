# %% [markdown]
# <a href="https://colab.research.google.com/github/stbhg5/ComputerScience/blob/main/python_ch12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Rest API

# %%
import requests
result = requests.get('https://map.naver.com/v5/api/geocode?request=coordsToaddr&version=1.0&sourcecrs=epsg:4326&output=json&orders=admcode,legalcode&coords=126.9476714877162,37.587676725659065')
result
# Out:
# <Response [200]>

# %%
# type(result)
result.json()
# Out:
# {'status': {'code': 0, 'name': 'ok', 'message': 'done'},
#  'results': [{'name': 'admcode',
#    'code': {'id': '1141065500', 'type': 'A', 'mappingId': '09410655'},
#    'region': {'area0': {'name': 'kr',
#      'coords': {'center': {'crs': '', 'x': 0.0, 'y': 0.0}}},
#     'area1': {'name': '서울특별시',
#      'coords': {'center': {'crs': 'EPSG:4326',
#        'x': 126.9783882,
#        'y': 37.5666103}},
#      'alias': '서울'},
#     'area2': {'name': '서대문구',
#      'coords': {'center': {'crs': 'EPSG:4326',
#        'x': 126.9368,
#        'y': 37.579225}}},
#     'area3': {'name': '홍제2동',
#      'coords': {'center': {'crs': 'EPSG:4326',
#        'x': 126.949338,
#        'y': 37.586107}}},
#     'area4': {'name': '',
#      'coords': {'center': {'crs': '', 'x': 0.0, 'y': 0.0}}}}},
#   {'name': 'legalcode',
#    'code': {'id': '1141011100', 'type': 'L', 'mappingId': '09410111'},
#    'region': {'area0': {'name': 'kr',
#      'coords': {'center': {'crs': '', 'x': 0.0, 'y': 0.0}}},
# ...

# %%
# 기업에서 제공하는 Rest API 사용하기
result = requests.get('https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EA%B0%95%EC%8A%B9%ED%98%84&oquery=%EA%B0%95%EC%8A%B9%ED%98%84&tqi=h%2BJx3wp0J14sssNcyO0ssssss%2BC-287963')
result.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="강승현 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'강승현\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'강승현\'의 네이버 통합검색 결과입니다."> <title>강승현 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_230216.css"> <link rel="stylesheet" type="text/css" hr
# ...

# %%
uri = 'https://apis.openapi.sk.com/tmap/geo/geocoding?version=1&city_do=경기도&gu_gun=성남 분당구&dong=정자동&appKey=신청해야받음' # .format(appKey='신청해야받음')
requests.get(uri).json()
# Out:
# {'error': {'id': '403',
#   'category': 'gw',
#   'code': 'INVALID_API_KEY',
#   'message': 'Forbidden'}}

# %%
requests.get(uri, headers = {'Accept': 'application/xml'}).text
# Out:
# '{\n  "error": {\n    "id": "403",\n    "category": "gw",\n    "code": "INVALID_API_KEY",\n    "message": "Forbidden"\n  }\n}'
